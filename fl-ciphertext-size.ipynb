# %%
# !pip install tenseal
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tenseal
#   Downloading tenseal-0.3.14-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 30.9 MB/s eta 0:00:00
# Installing collected packages: tenseal
# Successfully installed tenseal-0.3.14

# %%
import tenseal as ts
import numpy as np
import math

poly_mod_degree = 16384
coeff_mod_bit_sizes = [40, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 40]
# create TenSEALContext
context = ts.context(ts.SCHEME_TYPE.CKKS, poly_mod_degree, -1, coeff_mod_bit_sizes)
context.global_scale = 2 **  23
context.generate_galois_keys()

# %%
def convert_size(size_bytes):
    if size_bytes == 0:
        return "0B"
    size_name = ("B", "KB", "MB", "GB", "TB", "PB", "EB", "ZB", "YB")
    i = int(math.floor(math.log(size_bytes, 1024)))
    p = math.pow(1024, i)
    s = round(size_bytes / p, 2)
    return "%s %s" % (s, size_name[i])

# %%
x = [3.1416]
enc_x = ts.ckks_vector(context, x)
enc_x_serialize = enc_x.serialize()
convert_size(len(enc_x_serialize))
# Out:
# '1.86 MB'

# %%
# Out:
# '1.86 MB'
